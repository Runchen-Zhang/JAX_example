# %% [markdown]
# <a href="https://colab.research.google.com/github/Runchen-Zhang/JAX_example/blob/main/JAX_FHN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

import jax
import jax.numpy as jnp
from jax import jit, grad, value_and_grad, lax
import matplotlib.pyplot as plt
